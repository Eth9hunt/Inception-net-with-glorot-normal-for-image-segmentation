# %%
import tensorflow as tf

def inception_block(inputs, filters):
    tower_1 = tf.keras.layers.Conv2D(filters, (1, 1), padding='same', activation='relu')(inputs)
    tower_1 = tf.keras.layers.Conv2D(filters, (3, 3), padding='same', activation='relu')(tower_1)

    tower_2 = tf.keras.layers.Conv2D(filters, (1, 1), padding='same', activation='relu')(inputs)
    tower_2 = tf.keras.layers.Conv2D(filters, (5, 5), padding='same', activation='relu')(tower_2)

    tower_3 = tf.keras.layers.MaxPooling2D((3, 3), strides=(1, 1), padding='same')(inputs)
    tower_3 = tf.keras.layers.Conv2D(filters, (1, 1), padding='same', activation='relu')(tower_3)

    output = tf.keras.layers.concatenate([tower_1, tower_2, tower_3], axis=-1)
    return output

def inception_unet(input_shape, num_classes):
    inputs = tf.keras.Input(shape=input_shape)

    # Downsampling
    conv1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', kernel_initializer='glorot_normal')(inputs)
    conv1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv1)
    pool1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = inception_block(pool1, 128)
    conv2 = tf.keras.layers.Conv2D(128, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv2)
    conv2 = tf.keras.layers.Conv2D(128, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv2)
    pool2 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = inception_block(pool2, 256)
    conv3 = tf.keras.layers.Conv2D(256, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv3)
    conv3 = tf.keras.layers.Conv2D(256, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv3)
    pool3 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = inception_block(pool3, 512)
    conv4 = tf.keras.layers.Conv2D(512, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv4)
    conv4 = tf.keras.layers.Conv2D(512, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv4)
    pool4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv4)

    # Bridge
    conv5 = inception_block(pool4, 1024)
    conv5 = tf.keras.layers.Conv2D(1024, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv5)
    conv5 = tf.keras.layers.Conv2D(1024, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv5)

    # Upsampling
    up6 = tf.keras.layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(conv5)
    up6 = tf.keras.layers.concatenate([up6, conv4], axis=-1)
    conv6 = inception_block(up6, 512)
    conv6 = tf.keras.layers.Conv2D(512, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv6)
    conv6 = tf.keras.layers.Conv2D(512, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv6)

    up7 = tf.keras.layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6)
    up7 = tf.keras.layers.concatenate([up7, conv3], axis=-1)
    conv7 = inception_block(up7, 256)
    conv7 = tf.keras.layers.Conv2D(256, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv7)
    conv7 = tf.keras.layers.Conv2D(256, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv7)

    up8 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7)
    up8 = tf.keras.layers.concatenate([up8, conv2], axis=-1)
    conv8 = inception_block(up8, 128)
    conv8 = tf.keras.layers.Conv2D(128, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv8)
    conv8 = tf.keras.layers.Conv2D(128, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv8)

    up9 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8)
    up9 = tf.keras.layers.concatenate([up9, conv1], axis=-1)
    conv9 = inception_block(up9, 64)
    conv9 = tf.keras.layers.Conv2D(64, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv9)
    conv9 = tf.keras.layers.Conv2D(64, (1, 1), padding='same', activation='relu', kernel_initializer='glorot_normal')(conv9)

    # Output
    outputs = tf.keras.layers.Conv2D(num_classes, (1, 1), activation='softmax')(conv9)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    return model

# %%
# Define hyperparameters and other settings
input_shape = (256, 256, 1)
num_classes = 2
learning_rate = 0.001
num_epochs = 170

# Create the model
model = inception_unet(input_shape, num_classes)

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_59 (Conv2D)             (None, 256, 256, 64  640         ['input_2[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_59[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 128, 128, 64  0          ['conv2d_60[0][0]']
#  )                              )
#
#  conv2d_61 (Conv2D)             (None, 128, 128, 12  8320        ['max_pooling2d_12[0][0]']
#                                 8)
#
#  conv2d_63 (Conv2D)             (None, 128, 128, 12  8320        ['max_pooling2d_12[0][0]']
#                                 8)
#
#  max_pooling2d_13 (MaxPooling2D  (None, 128, 128, 64  0          ['max_pooling2d_12[0][0]']
#  )                              )
#
#  conv2d_62 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_61[0][0]']
#                                 8)
#
#  conv2d_64 (Conv2D)             (None, 128, 128, 12  409728      ['conv2d_63[0][0]']
#                                 8)
#
#  conv2d_65 (Conv2D)             (None, 128, 128, 12  8320        ['max_pooling2d_13[0][0]']
#                                 8)
#
#  concatenate_12 (Concatenate)   (None, 128, 128, 38  0           ['conv2d_62[0][0]',
#                                 4)                                'conv2d_64[0][0]',
#                                                                   'conv2d_65[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 128, 128, 12  49280       ['concatenate_12[0][0]']
#                                 8)
#
#  conv2d_67 (Conv2D)             (None, 128, 128, 12  16512       ['conv2d_66[0][0]']
#                                 8)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 64, 64, 128)  0          ['conv2d_67[0][0]']
#  )
#
#  conv2d_68 (Conv2D)             (None, 64, 64, 256)  33024       ['max_pooling2d_14[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 64, 64, 256)  33024       ['max_pooling2d_14[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 64, 64, 128)  0          ['max_pooling2d_14[0][0]']
#  )
#
#  conv2d_69 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_68[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 64, 64, 256)  1638656     ['conv2d_70[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 64, 64, 256)  33024       ['max_pooling2d_15[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 768)  0           ['conv2d_69[0][0]',
#                                                                   'conv2d_71[0][0]',
#                                                                   'conv2d_72[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 64, 64, 256)  196864      ['concatenate_13[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 64, 64, 256)  65792       ['conv2d_73[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 32, 32, 256)  0          ['conv2d_74[0][0]']
#  )
#
#  conv2d_75 (Conv2D)             (None, 32, 32, 512)  131584      ['max_pooling2d_16[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 32, 32, 512)  131584      ['max_pooling2d_16[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 32, 32, 256)  0          ['max_pooling2d_16[0][0]']
#  )
#
#  conv2d_76 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_75[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 32, 32, 512)  6554112     ['conv2d_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 32, 32, 512)  131584      ['max_pooling2d_17[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 32, 32, 1536  0           ['conv2d_76[0][0]',
#                                 )                                 'conv2d_78[0][0]',
#                                                                   'conv2d_79[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 32, 32, 512)  786944      ['concatenate_14[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 32, 32, 512)  262656      ['conv2d_80[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 16, 16, 512)  0          ['conv2d_81[0][0]']
#  )
#
#  conv2d_82 (Conv2D)             (None, 16, 16, 1024  525312      ['max_pooling2d_18[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 16, 16, 1024  525312      ['max_pooling2d_18[0][0]']
#                                 )
#
#  max_pooling2d_19 (MaxPooling2D  (None, 16, 16, 512)  0          ['max_pooling2d_18[0][0]']
#  )
#
#  conv2d_83 (Conv2D)             (None, 16, 16, 1024  9438208     ['conv2d_82[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 16, 16, 1024  26215424    ['conv2d_84[0][0]']
#                                 )
#
#  conv2d_86 (Conv2D)             (None, 16, 16, 1024  525312      ['max_pooling2d_19[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 16, 16, 3072  0           ['conv2d_83[0][0]',
#                                 )                                 'conv2d_85[0][0]',
#                                                                   'conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 16, 16, 1024  3146752     ['concatenate_15[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 16, 16, 1024  1049600     ['conv2d_87[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 512)  2097664    ['conv2d_88[0][0]']
#  spose)
#
#  concatenate_16 (Concatenate)   (None, 32, 32, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'conv2d_81[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 32, 32, 512)  524800      ['concatenate_16[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 32, 32, 512)  524800      ['concatenate_16[0][0]']
#
#  max_pooling2d_20 (MaxPooling2D  (None, 32, 32, 1024  0          ['concatenate_16[0][0]']
#  )                              )
#
#  conv2d_90 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_89[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 32, 32, 512)  6554112     ['conv2d_91[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 32, 32, 512)  524800      ['max_pooling2d_20[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 32, 32, 1536  0           ['conv2d_90[0][0]',
#                                 )                                 'conv2d_92[0][0]',
#                                                                   'conv2d_93[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 32, 32, 512)  786944      ['concatenate_17[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 32, 32, 512)  262656      ['conv2d_94[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 256)  524544     ['conv2d_95[0][0]']
#  spose)
#
#  concatenate_18 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'conv2d_74[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 64, 64, 256)  131328      ['concatenate_18[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 64, 64, 256)  131328      ['concatenate_18[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 64, 64, 512)  0          ['concatenate_18[0][0]']
#  )
#
#  conv2d_97 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_96[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 64, 64, 256)  1638656     ['conv2d_98[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 64, 64, 256)  131328      ['max_pooling2d_21[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 64, 64, 768)  0           ['conv2d_97[0][0]',
#                                                                   'conv2d_99[0][0]',
#                                                                   'conv2d_100[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 64, 64, 256)  196864      ['concatenate_19[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 64, 64, 256)  65792       ['conv2d_101[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 128, 128, 12  131200     ['conv2d_102[0][0]']
#  spose)                         8)
#
#  concatenate_20 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_transpose_6[0][0]',
#                                 6)                                'conv2d_67[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 128, 128, 12  32896       ['concatenate_20[0][0]']
#                                 8)
#
#  conv2d_105 (Conv2D)            (None, 128, 128, 12  32896       ['concatenate_20[0][0]']
#                                 8)
#
#  max_pooling2d_22 (MaxPooling2D  (None, 128, 128, 25  0          ['concatenate_20[0][0]']
#  )                              6)
#
#  conv2d_104 (Conv2D)            (None, 128, 128, 12  147584      ['conv2d_103[0][0]']
#                                 8)
#
#  conv2d_106 (Conv2D)            (None, 128, 128, 12  409728      ['conv2d_105[0][0]']
#                                 8)
#
#  conv2d_107 (Conv2D)            (None, 128, 128, 12  32896       ['max_pooling2d_22[0][0]']
#                                 8)
#
#  concatenate_21 (Concatenate)   (None, 128, 128, 38  0           ['conv2d_104[0][0]',
#                                 4)                                'conv2d_106[0][0]',
#                                                                   'conv2d_107[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 128, 128, 12  49280       ['concatenate_21[0][0]']
#                                 8)
#
#  conv2d_109 (Conv2D)            (None, 128, 128, 12  16512       ['conv2d_108[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 64  32832      ['conv2d_109[0][0]']
#  spose)                         )
#
#  concatenate_22 (Concatenate)   (None, 256, 256, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'conv2d_60[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 256, 256, 64  8256        ['concatenate_22[0][0]']
#                                 )
#
#  conv2d_112 (Conv2D)            (None, 256, 256, 64  8256        ['concatenate_22[0][0]']
#                                 )
#
#  max_pooling2d_23 (MaxPooling2D  (None, 256, 256, 12  0          ['concatenate_22[0][0]']
#  )                              8)
#
#  conv2d_111 (Conv2D)            (None, 256, 256, 64  36928       ['conv2d_110[0][0]']
#                                 )
#
#  conv2d_113 (Conv2D)            (None, 256, 256, 64  102464      ['conv2d_112[0][0]']
#                                 )
#
#  conv2d_114 (Conv2D)            (None, 256, 256, 64  8256        ['max_pooling2d_23[0][0]']
#                                 )
#
#  concatenate_23 (Concatenate)   (None, 256, 256, 19  0           ['conv2d_111[0][0]',
#                                 2)                                'conv2d_113[0][0]',
#                                                                   'conv2d_114[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 256, 256, 64  12352       ['concatenate_23[0][0]']
#                                 )
#
#  conv2d_116 (Conv2D)            (None, 256, 256, 64  4160        ['conv2d_115[0][0]']
#                                 )
#
#  conv2d_117 (Conv2D)            (None, 256, 256, 2)  130         ['conv2d_116[0][0]']
#
# ==================================================================================================
# Total params: 73,172,418
# Trainable params: 73,172,418
# Non-trainable params: 0
# __________________________________________________________________________________________________
